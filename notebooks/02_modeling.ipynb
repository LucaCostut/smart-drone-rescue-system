# %%
import pandas as pd

# Re-loading the dataset—had to tweak a few read settings to handle the formatting properly
df = pd.read_csv(
    '../data/911_Calls_for_Service.csv',
    sep='\t',
    on_bad_lines='skip',
    encoding='utf-8',
    engine='python'
)

# Converting the datetime column again (seems like a recurring task)
df['callDateTime'] = pd.to_datetime(df['callDateTime'], errors='coerce')

# Dropping an empty column and rows without timestamps
df.drop(columns=['Unnamed: 19'], inplace=True)
df = df.dropna(subset=['callDateTime'])

# Creating basic time-related features (these usually help a lot in modeling)
df['Hour'] = df['callDateTime'].dt.hour
df['DayOfWeek'] = df['callDateTime'].dt.day_name()
df['Month'] = df['callDateTime'].dt.month
df['Year'] = df['callDateTime'].dt.year

# Some quick cleanup for strings
df['description'] = df['description'].str.strip()
df['priority'] = df['priority'].str.strip()

# Filtering out rows with missing ZIP codes
df_model = df.dropna(subset=['ZIPCode'])

# To simplify the model, I'll keep only the top 10 ZIP codes (rest are too rare)
top_zips = df_model['ZIPCode'].value_counts().nlargest(10).index
df_model = df_model[df_model['ZIPCode'].isin(top_zips)]

# Picking features that might be predictive
features = df_model[['Hour', 'DayOfWeek', 'description', 'priority']]
target = df_model['ZIPCode']

# Encoding categorical variables (standard stuff)
from sklearn.preprocessing import LabelEncoder
le_day = LabelEncoder()
le_type = LabelEncoder()
le_priority = LabelEncoder()

features['DayOfWeek'] = le_day.fit_transform(features['DayOfWeek'])
features['description'] = le_type.fit_transform(features['description'])
features['priority'] = le_priority.fit_transform(features['priority'])
# Out:
# /var/folders/31/9x7_943517v2frgshb22nr_40000gn/T/ipykernel_66406/931613461.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['DayOfWeek'] = le_day.fit_transform(features['DayOfWeek'])
# /var/folders/31/9x7_943517v2frgshb22nr_40000gn/T/ipykernel_66406/931613461.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['description'] = le_type.fit_transform(features['description'])
# /var/folders/31/9x7_943517v2frgshb22nr_40000gn/T/ipykernel_66406/931613461.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['priority'] = le_priority.fit_transform(features['priority'])

# %% [markdown]
# ## Model Training: First Attempt
# Alright, let's train a basic model to see if we can predict ZIP codes based on call features. Nothing fancy for now—Random Forest should do.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# Basic train-test split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Going with a Random Forest for now—tends to work well out of the box
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Let's see how it does
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.15561707846386902
#               precision    recall  f1-score   support
#
#      21201.0       0.15      0.13      0.14     20289
#      21202.0       0.18      0.19      0.19     21442
#      21213.0       0.11      0.05      0.07     17154
#      21215.0       0.15      0.34      0.21     28615
#      21217.0       0.19      0.20      0.19     23588
#      21218.0       0.14      0.13      0.13     22862
#      21223.0       0.13      0.06      0.08     18440
#      21224.0       0.15      0.16      0.16     22635
#      21229.0       0.13      0.05      0.08     15436
#      21230.0       0.16      0.11      0.13     20120
#
#     accuracy                           0.16    210581
#    macro avg       0.15      0.14      0.14    210581
# weighted avg       0.15      0.16      0.14    210581

# %% [markdown]
# ## Simulate New Emergency Calls
# Trying to simulate what would happen if a new emergency call came in. Can we guess where it should be dispatched?

# %%
# Just simulating a call on a Monday afternoon for NARCOTICS, High priority
new_case = pd.DataFrame({
    'Hour': [14],
    'DayOfWeek': le_day.transform(['Monday']),
    'description': le_type.transform(['NARCOTICS']),
    'priority': le_priority.transform(['High'])
})

zip_prediction = model.predict(new_case)
print("Predicted ZIP code for dispatch:", zip_prediction[0])
# Out:
# Predicted ZIP code for dispatch: 21217.0

# %%
# Simulate 1000 future calls
import numpy as np

simulated_calls = pd.DataFrame({
    'Hour': np.random.randint(0, 24, 1000),
    'DayOfWeek': le_day.transform(np.random.choice(le_day.classes_, 1000)),
    'description': le_type.transform(np.random.choice(le_type.classes_, 1000)),
    'priority': le_priority.transform(np.random.choice(le_priority.classes_, 1000))
})

# Predict likely ZIPs for these calls
predicted_zips = model.predict(simulated_calls)

# Count frequency of ZIP predictions
from collections import Counter
zip_counts = Counter(predicted_zips)
top_zips = sorted(zip_counts.items(), key=lambda x: -x[1])[:5]

print("Top 5 ZIP codes to station drones:", top_zips)
# Out:
# Top 5 ZIP codes to station drones: [(np.float64(21215.0), 160), (np.float64(21202.0), 132), (np.float64(21217.0), 121), (np.float64(21224.0), 106), (np.float64(21218.0), 101)]

# %% [markdown]
# ## Step 5: Assign Drones Based on Prediction

# %%
# Simulate 5 drones
drones = ['Drone_A', 'Drone_B', 'Drone_C', 'Drone_D', 'Drone_E']
assigned_zips = [zip_[0] for zip_ in top_zips]

drone_deployment = dict(zip(drones, assigned_zips))
print("Drone Deployment Plan:")
for drone, zone in drone_deployment.items():
    print(f"{drone} stationed at ZIP {zone}")
# Out:
# Drone Deployment Plan:
# Drone_A stationed at ZIP 21215.0
# Drone_B stationed at ZIP 21202.0
# Drone_C stationed at ZIP 21217.0
# Drone_D stationed at ZIP 21224.0
# Drone_E stationed at ZIP 21218.0

# %% [markdown]
# ## Step 6: Map Drone Locations

# %%
import folium

# Approximate centroids for top ZIP codes (Baltimore area)
zip_coords = {
    21201.0: (39.2950, -76.6215),
    21202.0: (39.2970, -76.6089),
    21213.0: (39.3125, -76.5848),
    21215.0: (39.3455, -76.6806),
    21217.0: (39.3117, -76.6371),
    21218.0: (39.3289, -76.6099),
    21223.0: (39.2807, -76.6464),
    21224.0: (39.2842, -76.5584),
    21229.0: (39.2862, -76.6926),
    21230.0: (39.2686, -76.6093),
}
# Create map centered on Baltimore
baltimore_center = [39.29, -76.61]
m = folium.Map(location=baltimore_center, zoom_start=12)

# Plot drone assignments from previous simulation
for drone, zip_code in drone_deployment.items():
    if zip_code in zip_coords:
        lat, lon = zip_coords[zip_code]
        folium.Marker(
            location=[lat, lon],
            popup=f"{drone} (ZIP {int(zip_code)})",
            icon=folium.Icon(color='red', icon='info-sign')
        ).add_to(m)

# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_585f06f098902c97cdd267d8b8693b00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_585f06f098902c97cdd267d8b8693b00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_585f06f098902c97cdd267d8b8693b00 = L.map(
#                 &quot;map_585f06f098902c97cdd267d8b8693b00&quot;,
#                 {
#                     center: [39.29, -76.61],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2812b952703dc2ac9da42aac60d0af0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f2812b952703dc2ac9da42aac60d0af0.addTo(map_585f06f098902c97cdd267d8b8693b00);
#
#
#             var marker_51886280f6e43a7dffd1c6ecd6103278 = L.marker(
#                 [39.3455, -76.6806],
#                 {
# }
#             ).addTo(map_585f06f098902c97cdd267d8b8693b00);
#
#
#             var icon_16988fa92f14bfa7eda9c6748048cad8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a5719fee1d23d189e5b3ffd83f42549f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcad172a3d86076a7ca5302c7d126dae = $(`&lt;div id=&quot;html_fcad172a3d86076a7ca5302c7d126dae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Drone_A (ZIP 21215)&lt;/div&gt;`)[0];
#                 popup_a5719fee1d23d189e5b3ffd83f42549f.setContent(html_fcad172a3d86076a7ca5302c7d126dae);
#
#
#
#         marker_51886280f6e43a7dffd1c6ecd6103278.bindPopup(popup_a5719fee1d23d189e5b3ffd83f42549f)
#         ;
#
#
#
#
#                 marker_51886280f6e43a7dffd1c6ecd6103278.setIcon(icon_16988fa92f14bfa7eda9c6748048cad8);
#
#
#             var marker_f5cdca7e64e23cb781b40e3388c26b9f = L.marker(
#                 [39.297, -76.6089],
#                 {
# }
#             ).addTo(map_585f06f098902c97cdd267d8b8693b00);
#
#
#             var icon_c8a1e78b777935e4c7a96a314712f98f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cbb9753edd35d9949dac2ceb9000644b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34136fdbbf47f4406694b4cbc37f6d41 = $(`&lt;div id=&quot;html_34136fdbbf47f4406694b4cbc37f6d41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Drone_B (ZIP 21202)&lt;/div&gt;`)[0];
#                 popup_cbb9753edd35d9949dac2ceb9000644b.setContent(html_34136fdbbf47f4406694b4cbc37f6d41);
#
#
#
#         marker_f5cdca7e64e23cb781b40e3388c26b9f.bindPopup(popup_cbb9753edd35d9949dac2ceb9000644b)
#         ;
#
#
#
#
#                 marker_f5cdca7e64e23cb781b40e3388c26b9f.setIcon(icon_c8a1e78b777935e4c7a96a314712f98f);
#
#
#             var marker_d23b9c8885af2f78688a01c6d3ec08d4 = L.marker(
#                 [39.3117, -76.6371],
#                 {
# }
#             ).addTo(map_585f06f098902c97cdd267d8b8693b00);
#
#
#             var icon_3e3203a90e98745d996785d9eea58d83 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_22b958e2a334921c2619fdfca1ff99c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d5415999b1de080e55f569db919e5ad = $(`&lt;div id=&quot;html_0d5415999b1de080e55f569db919e5ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Drone_C (ZIP 21217)&lt;/div&gt;`)[0];
#                 popup_22b958e2a334921c2619fdfca1ff99c3.setContent(html_0d5415999b1de080e55f569db919e5ad);
#
#
#
#         marker_d23b9c8885af2f78688a01c6d3ec08d4.bindPopup(popup_22b958e2a334921c2619fdfca1ff99c3)
#         ;
#
#
#
#
#                 marker_d23b9c8885af2f78688a01c6d3ec08d4.setIcon(icon_3e3203a90e98745d996785d9eea58d83);
#
#
#             var marker_26a137261d2d59a1d934d0b

# %% [markdown]
# ## Step 7: Simulate Emergency Call Responses

# %%
import numpy as np

# Simulate 20 emergency calls
incoming_calls = pd.DataFrame({
    'Hour': np.random.randint(0, 24, 20),
    'DayOfWeek': le_day.transform(np.random.choice(le_day.classes_, 20)),
    'description': le_type.transform(np.random.choice(le_type.classes_, 20)),
    'priority': le_priority.transform(np.random.choice(le_priority.classes_, 20))
})

# Predict ZIPs for those calls
incoming_calls['PredictedZIP'] = model.predict(incoming_calls)

# Reverse the drone deployment mapping: ZIP → Drone
zip_to_drone = {v: k for k, v in drone_deployment.items()}

# Check which calls can be served instantly
def check_drone_response(zip_code):
    return zip_to_drone.get(zip_code, None)

incoming_calls['DroneAssigned'] = incoming_calls['PredictedZIP'].apply(check_drone_response)
incoming_calls['ResponseType'] = incoming_calls['DroneAssigned'].apply(
    lambda x: 'Immediate' if x is not None else 'Delayed'
)

# See the simulation result
incoming_calls[['PredictedZIP', 'DroneAssigned', 'ResponseType']].head(10)
# Out:
#    PredictedZIP DroneAssigned ResponseType
# 0       21202.0       Drone_B    Immediate
# 1       21224.0       Drone_D    Immediate
# 2       21223.0          None      Delayed
# 3       21201.0          None      Delayed
# 4       21218.0       Drone_E    Immediate
# 5       21202.0       Drone_B    Immediate
# 6       21230.0          None      Delayed
# 7       21229.0          None      Delayed
# 8       21223.0          None      Delayed
# 9       21201.0          None      Delayed

# %%
# Summary
print("Drone Response Simulation Summary:")
print(incoming_calls['ResponseType'].value_counts())
# Out:
# Drone Response Simulation Summary:
# ResponseType
# Immediate    11
# Delayed       9
# Name: count, dtype: int64
